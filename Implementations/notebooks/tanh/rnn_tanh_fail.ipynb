# %%
import sys
sys.path.append('../')

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

from MaskedRNN import MaskedDeepRNN

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'figure.figsize': (15, 8)})
sns.set_style('dark')
sns.set_palette('deep')

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# #### Import, shuffle and split dataset

# %%
data = pd.read_csv('test_data.csv')

# %%
print('Total length: {}'.format(len(data)))
# Out:
# Total length: 6250

# %% [markdown]
# #### Parameters

# %%
MODEL = 'rnn-tanh'

# %%
INPUT_SIZE = 128
EMBEDDING_DIM = 100
OUTPUT_SIZE = 2

HIDDEN_LAYERS = [50, 50, 50]

# %% [markdown]
# #### Helper functions

# %%
def create_variable(tensor):
    return Variable(tensor.to(device))

# %%
def pad_seq(vect_seqs, seq_lens, valid):
    seq_tensor = torch.zeros((len(vect_seqs), seq_lens.max())).long()
    
    for index, (seq, seq_len) in enumerate(zip(vect_seqs, seq_lens)):
        seq_tensor[index, :seq_len] = torch.LongTensor(seq)
        
    return create_variable(seq_tensor), create_variable(seq_lens), create_variable(valid)

# %%
def str2ascii(string):
    ascii_arr = [ord(s) for s in string]
    return ascii_arr, len(ascii_arr)

# %%
def make_variables(strings, valid):
    seqs_and_lens = [str2ascii(string)for string in strings]
    vect_seqs = [s[0] for s in seqs_and_lens]
    seq_lens = torch.LongTensor([s[1] for s in seqs_and_lens])
    valid = torch.LongTensor(valid)
    return pad_seq(vect_seqs, seq_lens, valid)

# %% [markdown]
# #### Model

# %%
class Model(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers: list, nonlinearity):
        super(Model, self).__init__()

        self.embedding = nn.Embedding(num_embeddings=input_size, embedding_dim=hidden_layers[0]).to(device)
        self.recurrent = MaskedDeepRNN(hidden_layers[0], hidden_layers, nonlinearity=nonlinearity).to(device)
        self.fc = nn.Linear(hidden_layers[-1], output_size).to(device)
        
    def forward(self, input):
        input = input.t()
        embedded = self.embedding(input)
        output = self.recurrent(embedded)
        return self.fc(output)

# %% [markdown]
# #### Train & Test

# %%
losses = pd.DataFrame()

# %%
def test(seq, target):
    input, seq_lengths, target = make_variables([seq], [target])
    output = model(input)
    loss = criterion(output, target)
    test_loss.append(loss)

# %%
# %%time
for i in range(1, 6):
    print('Run: {}'.format(i))
    model = Model(INPUT_SIZE, OUTPUT_SIZE, HIDDEN_LAYERS, nonlinearity='tanh').cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    model.load_state_dict(torch.load('./state_dicts/rnn-tanh-dict-{}.pt'.format(i)))

    test_loss = []
    for l in range(len(data)):
        test(data['string'][l], data['valid'][l])

    losses['Run {}'.format(i)] = [_l.item() for _l in test_loss]
# Out:
# Run: 1
# Run: 2
# Run: 3
# Run: 4
# Run: 5
# CPU times: user 4min 51s, sys: 4.39 s, total: 4min 55s
# Wall time: 4min 56s

# %% [markdown]
# #### Plot and save

# %%
losses['str_len'] = data['string'].str.len()

# %%
fig, ax1 = plt.subplots()
ax1.set_title('Test loss w.r.t string length')
ax1.set_xlabel('Length')
plt.xticks(range(11, 54), size=10)

ax1.set_ylabel('Loss')
ax1.set_ylim([0, 260])
for column in losses:
    if column != 'str_len':
        ax1.plot(losses.groupby(['str_len'])[column].sum(), label='Run {}'.format(column.split()[-1]))
ax1.tick_params(axis='y')
ax1.legend()

ax2 = ax1.twinx()
ax2.set_ylabel('Number of string')
ax2.bar(losses.groupby(['str_len'])['str_len'].count().index, losses.groupby(['str_len'])['str_len'].count().values, color='k', alpha=.1)
plt.savefig('./loss/{}-loss-len-dist.png'.format(MODEL));

# %% [markdown]
# #### Test loss w.r.t number of Valid-Invalid sequences

# %%
data['str_len'] = data['string'].str.len()
str_len = data.groupby(['str_len'])

# %%
length, valid, invalid = [], [], []

# %%
for key, _ in str_len:
    length.append(key)

    try:
        valid.append(str_len.get_group(key)['valid'].value_counts()[1])
    except KeyError:
        valid.append(0)
        
    try:
        invalid.append(str_len.get_group(key)['valid'].value_counts()[0])
    except KeyError:
        invalid.append(0)

# %%
validity_losses = pd.DataFrame({'str_len': length, 'valid': valid, 'invalid': invalid})

# %%
fig, ax1 = plt.subplots()
ax1.set_title('Test loss w.r.t number of Valid-Invalid sequences')
ax1.set_xlabel('Length')
plt.xticks(range(11, 54), size=10)

ax1.set_ylabel('Loss')
ax1.set_ylim([0, 260])
for column in losses:
    if column != 'str_len':
        ax1.plot(losses.groupby(['str_len'])[column].sum(), label='Run {}'.format(column.split()[-1]))
ax1.legend()

ax2 = ax1.twinx()
ax2.set_ylabel('Number of string')
ax2.set_ylim([0, 390])
plt.fill_between(validity_losses['str_len'], validity_losses['valid'], label='Valid', alpha=.1, color='g')
plt.fill_between(validity_losses['str_len'], validity_losses['invalid'], label='Invalid', alpha=.1, color='r')
plt.legend(loc='lower right')
plt.savefig('./loss/{}-loss-val-inval.png'.format(MODEL));

# %% [markdown]
# #### Correlation between lenght and validity of a sequence

# %%
validity_losses['mean_loss'] = pd.DataFrame(losses.groupby(['str_len'])['Run 1', 'Run 2', 'Run 3', 'Run 4', 'Run 5'].sum().mean(axis=1).values)

# %%
plt.title('Correlation between length and validity of a sequence')
sns.heatmap(validity_losses.drop(['str_len'], axis=1).corr(), annot=True)
plt.savefig('./loss/{}-loss-corr.png'.format(MODEL));
